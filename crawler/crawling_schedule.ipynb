# %% [markdown]
# # **이전 버전**

# %%
import re
import json
from datetime import datetime, timedelta
from collections import defaultdict
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from urllib.parse import urljoin

# 날짜 범위 파싱
def parse_date_range(raw_date: str, year: str):
    parts = re.split(r"\s*~\s*", raw_date)
    if len(parts) == 1:
        return [datetime.strptime(f"{year}.{parts[0].strip()}", "%Y.%m.%d")]
    start = datetime.strptime(f"{year}.{parts[0].strip()}", "%Y.%m.%d")
    end = datetime.strptime(f"{year}.{parts[1].strip()}", "%Y.%m.%d")
    return [start + timedelta(days=i) for i in range((end - start).days + 1)]

# 요일 추출
def get_korean_weekday(date_obj):
    days = ["월요일", "화요일", "수요일", "목요일", "금요일", "토요일", "일요일"]
    return days[date_obj.weekday()]

# 학기 분류 기준 설정
def determine_semester_and_academic_year(date_obj):
    y = date_obj.year
    if datetime(y, 3, 2) <= date_obj <= datetime(y, 6, 22):
        return "1학기", y
    elif datetime(y, 6, 23) <= date_obj <= datetime(y, 8, 31):
        return "여름방학", y
    elif datetime(y, 9, 1) <= date_obj <= datetime(y, 12, 22):
        return "2학기", y
    elif datetime(y, 12, 23) <= date_obj <= datetime(y, 12, 31):
        return "겨울방학", y + 1
    elif datetime(y, 1, 1) <= date_obj <= datetime(y, 3, 1):
        return "겨울방학", y
    return "학기미정", y

# 크롤링 코드
def crawl_hufs_schedule(url: str):
    options = Options()
    options.add_argument("--headless=new")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    iframe = driver.find_element("tag name", "iframe")
    iframe_url = urljoin(url, iframe.get_attribute("src"))
    driver.get(iframe_url)
    soup = BeautifulSoup(driver.page_source, "html.parser")
    driver.quit()

    table = soup.select_one("#timeTableList > ul")
    items = []
    current_year = None

    for el in table.children:
        if getattr(el, "name", None) is None:
            continue
        if el.name == "div":
            year = el.find("strong")
            if year:
                current_year = re.search(r"\d{4}", year.text.strip()).group()
        elif el.name == "li":
            if not current_year:
                y = soup.select_one(".month-search-header > p")
                if y: current_year = re.search(r"\d{4}", y.text.strip()).group()
            month = el.select_one("p.box-month")
            if not month: continue
            month_kr = month.text.strip()

            for e in el.select("div.list-inner > div.list-box"):
                d_tag = e.select_one("p.list-date")
                c_tag = e.select_one("p.list-content")
                if not d_tag or not c_tag: continue
                raw_date = d_tag.text.strip().replace(" ", "").replace("\n", "")
                content = c_tag.get_text(strip=True)

                try:
                    for d in parse_date_range(raw_date, current_year):
                        items.append({
                            "date": d.strftime("%Y-%m-%d"),
                            "date_obj": d,
                            "text": f"{d.year}년 {d.month}월 {d.day}일은 {content} 기간입니다.",
                            "month_kr": month_kr,
                            "weekday": get_korean_weekday(d)
                        })
                except:
                    continue

    structured = defaultdict(lambda: defaultdict(lambda: defaultdict(dict)))
    for i in items:
        d = i["date_obj"]
        semester, academic_year = determine_semester_and_academic_year(d)
        mon = i["month_kr"]
        structured[str(academic_year)][semester][mon][i["date"]] = {
            "text": i["text"],
            "weekday": i["weekday"]
        }

    return structured

# %%
# 실행
if __name__ == "__main__":
    url = "https://www.hufs.ac.kr/hufs/11360/subview.do"
    data = crawl_hufs_schedule(url)

    with open("hufs_schedule.json", "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

    print("✅ 학년도 기준으로 hufs_schedule.json 저장 완료!")
# Out:
# ✅ 학년도 기준으로 hufs_schedule.json 저장 완료!

# %%
data
# Out:
# defaultdict(<function __main__.crawl_hufs_schedule.<locals>.<lambda>()>,
#             {'2025': defaultdict(<function __main__.crawl_hufs_schedule.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'겨울방학': defaultdict(dict,
#                                       {'3월': {'2025-03-01': {'text': '2025년 3월 1일은 삼일절 기간입니다.',
#                                          'weekday': '토요일'}}}),
#                           '1학기': defaultdict(dict,
#                                       {'3월': {'2025-03-03': {'text': '2025년 3월 3일은 제1학기 개강 ·대체휴업일 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-03-04': {'text': '2025년 3월 4일은 수강신청 변경 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-03-05': {'text': '2025년 3월 5일은 수강신청 변경 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-03-06': {'text': '2025년 3월 6일은 수강신청 변경 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-03-07': {'text': '2025년 3월 7일은 수강신청 변경 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-03-08': {'text': '2025년 3월 8일은 수강신청 변경 기간입니다.',
#                                          'weekday': '토요일'},
#                                         '2025-03-09': {'text': '2025년 3월 9일은 수강신청 변경 기간입니다.',
#                                          'weekday': '일요일'},
#                                         '2025-03-10': {'text': '2025년 3월 10일은 수강신청 변경 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-03-24': {'text': '2025년 3월 24일은 수강신청 취소 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-03-25': {'text': '2025년 3월 25일은 수강신청 취소 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-03-26': {'text': '2025년 3월 26일은 수강신청 취소 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-03-27': {'text': '2025년 3월 27일은 수강신청 취소 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-03-28': {'text': '2025년 3월 28일은 제1학기 1/4선 기간입니다.',
#                                          'weekday': '금요일'}},
#                                        '4월': {'2025-04-20': {'text': '2025년 4월 20일은 제71주년 개교기념일 기간입니다.',
#                                          'weekday': '일요일'},
#                                         '2025-04-21': {'text': '2025년 4월 21일은 제1학기 중간시험 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-04-22': {'text': '2025년 4월 22일은 제1학기 중간시험 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-04-23': {'text': '2025년 4월 23일은 제1학기 중간시험 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-04-24': {'text': '2025년 4월 24일은 제1학기 중간시험 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-04-25': {'text': '2025년 4월 25일은 제1학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-04-26': {'text': '2025년 4월 26일은 제1학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '토요일'},
#                                         '2025-04-27': {'text': '2025년 4월 27일은 제1학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '일요일'},
#                                         '2025-04-28': {'text': '2025년 4월 28일은 제1학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-04-29': {'text': '2025년 4월 29일은 제1학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-04-30': {'text': '2025년 4월 30일은 제1학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-05-01': {'text': '2025년 5월 1일은 제1학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-05-02': {'text': '2025년 5월 2일은 제1학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '금요일'}},
#                                        '5월': {'2025-05-01': {'text': '2025년 5월 1일은 근로자의 날 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-05-05': {'text': '2025년 5월 5일은 어린이날·부처님오신날 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-05-06': {'text': '2025년 5월 6일은 대체휴업일 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-05-23': {'text': '2025년 5월 23일은 제1학기 3/4선 기간입니다.',
#                                          'weekday': '금요일'}},
#                                        '6월': {'2025-06-06': {'text': '2025년 6월 6일은 현충일 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-06-09': {'text': '2025년 6월 9일은 제1학기 보강주간 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-06-10': {'text': '2025년 6월 10일은 제1학기 보강주간 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-06-11': {'text': '2025년 6월 11일은 제1학기 보강주간 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-06-12': {'text': '2025년 6월 12일은 제1학기 보강주간 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-06-13': {'text': '2025년 6월 13일은 졸업시험 성적보고서 및 졸업논문 심사보고서 제출 마감 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-06-16': {'text': '2025년 6월 16일은 제1학기 기말시험 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-06-17': {'text': '2025년 6월 17일은 제1학기 기말시험 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-06-18': {'text': '2025년 6월 18일은 제1학기 기말시험 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-06-19': {'text': '2025년 6월 19일은 제1학기 기말시험 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-06-20': {'text': '2025년 6월 20일은 제1학기 성적입력 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-06-21': {'text': '2025년 6월 21일은 제1학기 성적입력 기간입니다.',
#                                          'weekday': '토요일'},
#                                         '2025-06-22': {'text': '2025년 6월 22일은 제1학기 성적입력 기간입니다.',
#                                          'weekday': '일요일'}}}),
#                           '여름방학': defaultdict(dict,
#                                       {'6월': {'2025-06-23': {'text': '2025년 6월 23일은 하계방학 및 계절학기 개강 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-06-24': {'text': '2025년 6월 24일은 제1학기 성적입력 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-06-25': {'text': '2025년 6월 25일은 제1학기 성적입력 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-06-26': {'text': '2025년 6월 26일은 제1학기 성적입력 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-06-27': {'text': '2025년 6월 27일은 제1학기 성적입력 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-06-30': {'text': '2025년 6월 30일은 제1학기 성적 열람 및 정정 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-07-01': {'text': '2025년 7월 1일은 제1학기 성적 열람 및 정정 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-07-02': {'text': '2025년 7월 2일은 제1학기 성적 열람 및 정정 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-07-03': {'text': '2025년 7월 3일은 제1학기 성적 열람 및 정정 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-07-04': {'text': '2025년 7월 4일은 제1학기 성적 열람 및 정정 기간입니다.',
#                                          'weekday': '금요일'}},
#                                        '7월': {'2025-07-11': {'text': '2025년 7월 11일은 계절학기 종강 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-07-30': {'text': '2025년 7월 30일은 2025년 후기 졸업 사정회의 기간입니다.',
#                                          'weekday': '수요일'}},
#                                        '8월': {'2025-08-04': {'text': '2025년 8월 4일은 제2학기 수강신청 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-08-05': {'text': '2025년 8월 5일은 제2학기 수강신청 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-08-06': {'text': '2025년 8월 6일은 제2학기 수강신청 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-08-07': {'text': '2025년 8월 7일은 제2학기 수강신청 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-08-08': {'text': '2025년 8월 8일은 제2학기 수강신청 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-08-15': {'text': '2025년 8월 15일은 광복절 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-08-22': {'text': '2025년 8월 22일은 2025년 후기 학위수여식 기간입니다.',
#                                          'weekday': '금요일'}}}),
#                           '2학기': defaultdict(dict,
#                                       {'9월': {'2025-09-01': {'text': '2025년 9월 1일은 수강신청 변경 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-09-02': {'text': '2025년 9월 2일은 수강신청 변경 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-09-03': {'text': '2025년 9월 3일은 수강신청 변경 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-09-04': {'text': '2025년 9월 4일은 수강신청 변경 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-09-05': {'text': '2025년 9월 5일은 수강신청 변경 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-09-22': {'text': '2025년 9월 22일은 수강신청 취소 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-09-23': {'text': '2025년 9월 23일은 수강신청 취소 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-09-24': {'text': '2025년 9월 24일은 수강신청 취소 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-09-25': {'text': '2025년 9월 25일은 수강신청 취소 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-09-26': {'text': '2025년 9월 26일은 제2학기 1/4선 기간입니다.',
#                                          'weekday': '금요일'}},
#                                        '10월': {'2025-10-03': {'text': '2025년 10월 3일은 개천절 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-10-05': {'text': '2025년 10월 5일은 추석 기간입니다.',
#                                          'weekday': '일요일'},
#                                         '2025-10-06': {'text': '2025년 10월 6일은 추석 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-10-07': {'text': '2025년 10월 7일은 추석 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-10-08': {'text': '2025년 10월 8일은 대체휴업일 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-10-09': {'text': '2025년 10월 9일은 한글날 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-10-20': {'text': '2025년 10월 20일은 제2학기 중간시험 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-10-21': {'text': '2025년 10월 21일은 제2학기 중간시험 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-10-22': {'text': '2025년 10월 22일은 제2학기 중간시험 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-10-23': {'text': '2025년 10월 23일은 제2학기 중간시험 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-10-24': {'text': '2025년 10월 24일은 제2학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-10-25': {'text': '2025년 10월 25일은 제2학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '토요일'},
#                                         '2025-10-26': {'text': '2025년 10월 26일은 제2학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '일요일'},
#                                         '2025-10-27': {'text': '2025년 10월 27일은 제2학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-10-28': {'text': '2025년 10월 28일은 제2학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-10-29': {'text': '2025년 10월 29일은 제2학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-10-30': {'text': '2025년 10월 30일은 제2학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-10-31': {'text': '2025년 10월 31일은 제2학기 중간성적 입력 및 확인 기간입니다.',
#                                          'weekday': '금요일'}},
#                                        '11월': {'2025-11-21': {'text': '2025년 11월 21일은 제2학기 3/4선 기간입니다.',
#                                          'weekday': '금요일'}},
#                                        '12월': {'2025-12-08': {'text': '2025년 12월 8일은 제2학기 보강주간 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-12-09': {'text': '2025년 12월 9일은 제2학기 보강주간 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-12-10': {'text': '2025년 12월 10일은 제2학기 보강주간 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-12-11': {'text': '2025년 12월 11일은 제2학기 보강주간 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-12-12': {'text': '2025년 12월 12일은 졸업시험 성적보고서 및 졸업논문 심사보고서 제출 마감 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-12-15': {'text': '2025년 12월 15일은 제2학기 기말시험 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2025-12-16': {'text': '2025년 12월 16일은 제2학기 기말시험 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-12-17': {'text': '2025년 12월 17일은 제2학기 기말시험 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-12-18': {'text': '2025년 12월 18일은 제2학기 기말시험 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-12-19': {'text': '2025년 12월 19일은 제2학기 성적입력 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2025-12-20': {'text': '2025년 12월 20일은 제2학기 성적입력 기간입니다.',
#                                          'weekday': '토요일'},
#                                         '2025-12-21': {'text': '2025년 12월 21일은 제2학기 성적입력 기간입니다.',
#                                          'weekday': '일요일'},
#                                         '2025-12-22': {'text': '2025년 12월 22일은 동계방학 및 계절학기 개강 기간입니다.',
#                                          'weekday': '월요일'}}})}),
#              '2026': defaultdict(<function __main__.crawl_hufs_schedule.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'겨울방학': defaultdict(dict,
#                                       {'12월': {'2025-12-23': {'text': '2025년 12월 23일은 제2학기 성적입력 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2025-12-24': {'text': '2025년 12월 24일은 제2학기 성적입력 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2025-12-25': {'text': '2025년 12월 25일은 성탄절 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2025-12-26': {'text': '2025년 12월 26일은 제2학기 성적입력 기간입니다.',
#                                          'weekday': '금요일'}},
#                                        '1월': {'2026-01-01': {'text': '2026년 1월 1일은 신정 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2026-01-13': {'text': '2026년 1월 13일은 계절학기 종강 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2026-01-28': {'text': '2026년 1월 28일은 2026년 전기 졸업 사정회의 기간입니다.',
#                                          'weekday': '수요일'}},
#                                        '2월': {'2026-02-02': {'text': '2026년 2월 2일은 2026학년도 제1학기 수강신청 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2026-02-03': {'text': '2026년 2월 3일은 2026학년도 제1학기 수강신청 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2026-02-04': {'text': '2026년 2월 4일은 2026학년도 제1학기 수강신청 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2026-02-05': {'text': '2026년 2월 5일은 2026학년도 제1학기 수강신청 기간입니다.',
#                                          'weekday': '목요일'},
#                                         '2026-02-06': {'text': '2026년 2월 6일은 2026학년도 제1학기 수강신청 기간입니다.',
#                                          'weekday': '금요일'},
#                                         '2026-02-16': {'text': '2026년 2월 16일은 설날 연휴 기간입니다.',
#                                          'weekday': '월요일'},
#                                         '2026-02-17': {'text': '2026년 2월 17일은 설날 연휴 기간입니다.',
#                                          'weekday': '화요일'},
#                                         '2026-02-18': {'text': '2026년 2월 18일은 설날 연휴 기간입니다.',
#                                          'weekday': '수요일'},
#                                         '2026-02-20': {'text': '2026년 2월 20일은 2026년 전기 학위수여식 기간입니다.',
#                                          'weekday': '금요일'}}})})})

# %% [markdown]
# # **수정 버전(25.05.19일자 수정)**

# %%
import re
import json
from datetime import datetime, timedelta
from collections import defaultdict
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from urllib.parse import urljoin

# 날짜 범위 파싱
def parse_date_range(raw_date: str, year: str):
    parts = re.split(r"\s*~\s*", raw_date)
    if len(parts) == 1:
        return [datetime.strptime(f"{year}.{parts[0].strip()}", "%Y.%m.%d")]
    start = datetime.strptime(f"{year}.{parts[0].strip()}", "%Y.%m.%d")
    end = datetime.strptime(f"{year}.{parts[1].strip()}", "%Y.%m.%d")
    return [start + timedelta(days=i) for i in range((end - start).days + 1)]

# 요일 추출
def get_korean_weekday(date_obj):
    days = ["월요일", "화요일", "수요일", "목요일", "금요일", "토요일", "일요일"]
    return days[date_obj.weekday()]

# 학기 분류 기준 설정
def determine_semester_and_academic_year(date_obj):
    y = date_obj.year
    if datetime(y, 3, 2) <= date_obj <= datetime(y, 6, 22):
        return "1학기", y
    elif datetime(y, 6, 23) <= date_obj <= datetime(y, 8, 31):
        return "여름방학", y
    elif datetime(y, 9, 1) <= date_obj <= datetime(y, 12, 22):
        return "2학기", y
    elif datetime(y, 12, 23) <= date_obj <= datetime(y, 12, 31):
        return "겨울방학", y + 1
    elif datetime(y, 1, 1) <= date_obj <= datetime(y, 3, 1):
        return "겨울방학", y
    return "학기미정", y

# 크롤링 코드
def crawl_hufs_schedule(url: str):
    options = Options()
    options.add_argument("--headless=new")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    iframe = driver.find_element("tag name", "iframe")
    iframe_url = urljoin(url, iframe.get_attribute("src"))
    driver.get(iframe_url)
    soup = BeautifulSoup(driver.page_source, "html.parser")
    driver.quit()

    table = soup.select_one("#timeTableList > ul")
    items = []
    current_year = None

    for el in table.children:
        if getattr(el, "name", None) is None:
            continue
        if el.name == "div":
            year = el.find("strong")
            if year:
                current_year = re.search(r"\d{4}", year.text.strip()).group()
        elif el.name == "li":
            if not current_year:
                y = soup.select_one(".month-search-header > p")
                if y: current_year = re.search(r"\d{4}", y.text.strip()).group()
            month = el.select_one("p.box-month")
            if not month: continue
            month_kr = month.text.strip()

            for e in el.select("div.list-inner > div.list-box"):
                d_tag = e.select_one("p.list-date")
                c_tag = e.select_one("p.list-content")
                if not d_tag or not c_tag: continue
                raw_date = d_tag.text.strip().replace(" ", "").replace("\n", "")
                content = c_tag.get_text(strip=True)

                try:
                    for d in parse_date_range(raw_date, current_year):
                        items.append({
                            "date": d.strftime("%Y-%m-%d"),
                            "date_obj": d,
                            "text": f"{d.year}년 {d.month}월 {d.day}일은 {content} 기간입니다.",
                            "month_kr": month_kr,
                            "weekday": get_korean_weekday(d)
                        })
                except:
                    continue

    # 초기화
    structured = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: defaultdict(dict))))
    
    # 누적 저장 로직
    for i in items:
        d = i["date_obj"]
        semester, academic_year = determine_semester_and_academic_year(d)
        mon = i["month_kr"]
        date_key = i["date"]
    
        # 이벤트 누적
        structured[str(academic_year)][semester][mon][date_key].setdefault("events", []).append({
            "text": i["text"],
            "weekday": i["weekday"]
        })

    return structured

# %%
# 실행
if __name__ == "__main__":
    url = "https://www.hufs.ac.kr/hufs/11360/subview.do"
    data = crawl_hufs_schedule(url)

    with open("hufs_schedule.json", "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

    print("✅ 학년도 기준으로 hufs_schedule.json 저장 완료!")
# Out:
# ✅ 학년도 기준으로 hufs_schedule.json 저장 완료!
